# %% [markdown]
# ### Nama    : Mitslina
# ### NIM     : 24060121130068
# ### Dataset : Dry Bean Dataset
# ### Link    : https://archive.ics.uci.edu/dataset/602/dry+bean+dataset

# %%
# import file gdrive lokal
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# import library pandas
import pandas as pd

# %%
# menuliskan path gdrive lokal yang sesuai
path = "/content/gdrive/MyDrive/PrakPM/Dry_Bean_Dataset.xlsx"
# memberikan nama dari fitur (kolom) yang akan digunakan
names = ['area', 'perimeter', 'majorAxisLength', 'minorAxisLength', 'aspectRation', 'eccentricity', 'convexArea', 'equivDiameter', 'extent', 'solidity', 'roundness', 'compactness', 'shapeFactor1', 'shapeFactor2', 'shapeFactor3', 'shapeFactor4', 'class']
# memuat dataset excel sesuai variabel path dan names
dataset = pd.read_excel(path, names=names)

# %% [markdown]
# ## Penjelasan:
# dataset berupa file excel dengan nama file Dry_Bean_Dataset.xlsx
# Berikut penjelasan mengenai dataset dry bean:
#
# Dalam penelitian ini, tujuh jenis kacang kering yang memiliki karakteristik serupa, seperti bentuk, tipe, dan struktur yang terkait dengan situasi pasar, digunakan. Sebuah sistem visi komputer dikembangkan untuk mengklasifikasikan secara seragam ketujuh variasi kacang kering yang hampir mirip satu sama lain. Untuk tujuan model klasifikasi, sebanyak 13.611 gambar biji kacang dari ketujuh jenis tersebut diambil menggunakan kamera beresolusi tinggi. Kemudian, gambar biji kacang yang dihasilkan oleh sistem visi komputer melalui tahap segmentasi dan ekstraksi fitur, menghasilkan sejumlah 16 fitur, termasuk 12 dimensi dan 4 bentuk. Hasil ini membentuk dasar data yang kuat untuk melatih model klasifikasi guna membedakan dan mengklasifikasikan kacang-kacang tersebut berdasarkan ciri-ciri yang ditemukan.
#
# Berikut Penjelasan Fitur:
#
# - Luas (A): Luas zona kacang dan jumlah piksel dalam batasnya.
#
# - Keliling (P): Keliling kacang didefinisikan sebagai panjang batasnya.
#
# - Panjang sumbu mayor (L): Jarak antara ujung-ujung garis terpanjang yang dapat ditarik dari kacang.
#
# - Panjang sumbu minor (l): Garis terpanjang yang dapat ditarik dari kacang saat berdiri tegak lurus terhadap sumbu utama.
#
# - Rasio aspek (K): Mendefinisikan hubungan antara L dan l.
#
# - Eksentrisitas (Ec): Eksentrisitas elips yang memiliki momen yang sama dengan wilayahnya.
#
# - Luas cembung (C): Jumlah piksel dalam poligon cembung terkecil yang dapat memuat luas biji kacang.
#
# - Diameter setara (Ed): Diameter lingkaran yang memiliki luas yang sama dengan luas biji kacang.
#
# - Extent (Ex): Rasio piksel dalam kotak pembatas terhadap luas biji kacang.
#
# - Kerataan (S): Juga dikenal sebagai kerataan. Rasio piksel dalam cangkang cembung terhadap yang ditemukan dalam biji kacang.
#
# - Bulatan (R): Dihitung dengan rumus berikut: (4πA)/(P^2)
#
# - Kompakness (CO): Mengukur bulatan suatu objek: Ed/L
#
# - Faktor Bentuk 1 (SF1), Faktor Bentuk 2 (SF2), Faktor Bentuk 3 (SF3),  Faktor Bentuk 4 (SF4)
#
# - Kelas (Seker, Barbunya, Bombay, Cali, Dermosan, Horoz, dan Sira)

# %% [markdown]
# ### 2. Melakukan Summary Dataset

# %% [markdown]
# a. Menentukan Dimensi Dataset

# %%
# Melihat dimensi dataset
print(dataset.shape)
# Out:
# (13611, 17)

# %% [markdown]
# ## Penjelasan:
# Hasilnya dataset tersebut terdiri dari 13.611 instance/sampel data dan 17 atribut/fitur data.

# %% [markdown]
# ### b. Melihat Isi Dataset

# %%
# menampilkan isi dataset
pd.DataFrame(dataset.head(20))
# Out:
#      area  perimeter  majorAxisLength  minorAxisLength  aspectRation  \
# 0   28395    610.291       208.178117       173.888747      1.197191
# 1   28734    638.018       200.524796       182.734419      1.097356
# 2   29380    624.110       212.826130       175.931143      1.209713
# 3   30008    645.884       210.557999       182.516516      1.153638
# 4   30140    620.134       201.847882       190.279279      1.060798
# 5   30279    634.927       212.560556       181.510182      1.171067
# 6   30477    670.033       211.050155       184.039050      1.146768
# 7   30519    629.727       212.996755       182.737204      1.165591
# 8   30685    635.681       213.534145       183.157146      1.165852
# 9   30834    631.934       217.227813       180.897469      1.200834
# 10  30917    640.765       213.560089       184.439871      1.157885
# 11  31091    638.558       210.486255       188.326848      1.117665
# 12  31107    640.594       214.648549       184.969253      1.160455
# ...

# %% [markdown]
# ## Penjelasan:
# Hasilnya akan tampil data dengan menggunakan frame pada 20 baris data pertama

# %% [markdown]
# ### c. Distribusi Kelas Data

# %%
# distribusi kelas data
print(dataset.groupby('class').size())
# Out:
# class
# BARBUNYA    1322
# BOMBAY       522
# CALI        1630
# DERMASON    3546
# HOROZ       1928
# SEKER       2027
# SIRA        2636
# dtype: int64

# %% [markdown]
# ### Penjelasan:
#
# Output yang diberikan adalah hasil dari pengelompokan data berdasarkan kelas atau kategori 'class' dalam dataset. Data telah dikelompokkan berdasarkan kelas 'class', dan kemudian dihitung jumlah data yang termasuk dalam setiap kelas tersebut.
#
# Contohnya, kelas 'BARBUNYA' memiliki 1322 data, kelas 'BOMBAY' memiliki 522 data, kelas 'CALI' memiliki 1630 data, dan seterusnya untuk kelas-kelas lainnya. Ini memberikan informasi tentang seberapa banyak data yang termasuk dalam masing-masing kelas dalam dataset. Hal ini berguna untuk memahami sebaran atau distribusi data di antara kelas-kelas yang ada, yang dapat digunakan dalam analisis dan pemrosesan data lebih lanjut.

# %% [markdown]
# ### d. Ringkasan Statsitik

# %%
# ringkasan statistik
dataset.describe()
# Out:
#                 area     perimeter  majorAxisLength  minorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        aspectRation  eccentricity     convexArea  equivDiameter        extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %% [markdown]
# ### Penjelasan:
# Hasilnya akan tampil statistik data meliputi
# count, mean, standard deviasi, nilai min, nilai max, dan quartile (25%, 50%, 75%) untuk setiap fiturnya.
#
# Ringkasan statistik ini membantu kita memahami sebaran data dalam setiap fitur yang dapat digunakan dalam menganalisis data

# %% [markdown]
# ### e. visualisasi data menggunakan plot unvariant

# %%
# visualisasi data menggunakan plot unvariant (box diagram)
# mengimport matplotlib.pyplot
import matplotlib.pyplot as plt

# Ubah ukuran figur
fig = plt.figure(figsize=(12, 10))

# Membuat subplot
# kind: jenis diagram
# subplots=True: membuat subplot terpisah untuk setiap fitur dalam dataset.
# layout: mengatur tata letak subplot (baris, kolom).
# sharex=False dan sharey=False: antar subplot tidak akan memiliki sumbu x dan y yang sama.
# ax=fig.gca() mengacu pada objek "fig" yang telah dibuat sebelumnya.
dataset.plot(kind='box', subplots=True, layout=(4, 4), sharex=False, sharey=False, ax=fig.gca())

# Mengatur jarak antara subplot
plt.tight_layout()

# Menampilkan diagram box
plt.show()
# Out:
# <ipython-input-10-5b3200c51e4b>:14: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   dataset.plot(kind='box', subplots=True, layout=(4, 4), sharex=False, sharey=False, ax=fig.gca())

# %% [markdown]
# ### Penjelasan:
# Plot univariat adalah plot dari masing-masing variabel individu.
# Mengingat bahwa variabel inputnya numerik, kita bisa membuat jenis
# plot box. Interpretasi dari box plot bergantung pada tujuan analisis. Box plot membantu dalam memahami sebaran data, nilai median, serta keberadaan pencilan. Ini adalah alat yang berguna dalam analisis eksploratori data dan membandingkan sekelompok data.
#
# Berikut yang dapat diinterpretasi dari diagram box:
# Interpretasi dari sebuah box plot melibatkan pemahaman terhadap berbagai elemen dalam plot tersebut. Berikut adalah cara untuk menginterpretasi box plot:
#
# - Kotak (Box): Kotak pada box plot mewakili interkuartil range (IQR), yang mencakup sekitar 50% data di tengah distribusi. Batas bawah kotak menunjukkan nilai kuartil pertama (Q1), sedangkan batas atas kotak menunjukkan nilai kuartil ketiga (Q3). Kotak itu sendiri melambangkan sebaran data antara Q1 dan Q3.
#
# - Garis Tengah di Kotak: Garis tengah di dalam kotak adalah nilai median (Q2) dari data, yang membagi data menjadi dua bagian yang sama dari segi jumlah.
#
# - Whisker Atas dan Whisker Bawah: Garis-garis yang menghubungkan kotak ke titik-titik di atas dan di bawahnya menunjukkan jangkauan data di luar IQR. Garis-garis ini biasanya ditarik hingga batas atas dan batas bawah data yang tidak dianggap sebagai pencilan. Pencilan mungkin muncul sebagai titik-titik di luar garis whiskers.
#
# - Pencilan (Outliers): Titik-titik di luar batas atas dan batas bawah garis whiskers adalah pencilan. Pencilan adalah data-data yang jauh dari nilai-nilai utama distribusi dan perlu diperhatikan dalam analisis data.
#
# - Posisi dan Panjang Kotak: Posisi kotak di sepanjang sumbu horizontal menunjukkan letak pusat distribusi data, sedangkan panjang kotak menggambarkan sebaran data dalam IQR.
#
# - Arah dan Panjang whiskers: Arah dan panjang garis whisker menunjukkan sejauh mana data menyebar di luar IQR. Jika whisker lebih panjang, ini menunjukkan distribusi data yang lebih luas.
#
# - Skewness adalah konsep dalam statistik yang mengacu pada kemiringan atau asimetri dalam distribusi data. Ini mengukur sejauh mana distribusi data cenderung condong ke satu arah, baik ke kanan (positif skewness) atau ke kiri (negatif skewness), atau apakah distribusi data cenderung simetris. Terdapat tiga jenis skewness sebagai berikut
#
#  a. Positif (Right-Skewed): Jika data cenderung miring ke kanan, maka distribusinya dikatakan positif atau right-skewed. Ini berarti sebagian besar data terkumpul di sebelah kiri dan upper whisker cenderung lebih panjang dari lower whisker karena ekor yang lebih panjang di sebelah kanan.
#
#  b. Negatif (Left-Skewed): Jika data cenderung miring ke kiri, maka distribusinya dikatakan negatif atau left-skewed. Ini berarti sebagian besar data terkumpul di sebelah kanan dan lower whisker cenderung lebih panjang dari upper whisker karena ekor yang lebih panjang di sebelah kiri.
#
#  c. Simetris (No Skew): Jika data terdistribusi secara simetris, maka distribusinya dikatakan tidak miring (no skew). Ini berarti data terdistribusi secara merata di sekitar nilai tengahnya, dan skewnessnya mendekati nol.
#
# ### Kesimpulan:
# Berdasarkan data yang dihasilkan dengan diagram box masing-masing fitur memiliki sebaran data, nilai median, serta keberadaan pencilan yang berbeda-beda. Seperti pada fitur shapeFactor3 yang memiliki sebaran data yang cenderung ke arah kanan karena adanya pencilan atas pada data di atas Q3, pada fitur shapeFactor4 memiliki sebaran data yang cenderung ke arah kiri karena adanya pencilan bawah pada data di bawah Q1, sedangkan pada shapeFactor1 sebaran data simetris yaitu terdistribusi secara merata di sekitar median Q2.

# %%
# visualisasi data menggunakan plot unvariant (histogram)
# Ubah ukuran figur
fig = plt.figure(figsize=(22, 18))

# Membuat histogram untuk setiap fitur dalam dataset
# dataset.hist(): untuk membuat histogram untuk setiap fitur dalam dataset.
# bins: defaultnya 10 interval. Parameter ini mengatur jumlah "batang" atau interval dalam histogram. Dalam hal ini, setiap histogram akan memiliki 20 interval.
# color: mengatur warna histogram.
# edgecolor: mengatur warna border batang dalam histogram.
# grid=False: Ini mengatur apakah grid akan ditampilkan di latar belakang histogram (default adalah False).
# ax=fig.gca(): Ini mengacu pada objek "fig" yang telah dibuat sebelumnya.
dataset.hist(color='skyblue', edgecolor='black', grid=False, ax=fig.gca())

# Mengatur jarak antara subplot
plt.tight_layout()

# Menampilkan histogram
plt.show()
# Out:
# <ipython-input-19-11d24b41f4f6>:12: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   dataset.hist(color='skyblue', edgecolor='black', grid=False, ax=fig.gca())

# %% [markdown]
# # Penjelasan:
# Hasilnya yaitu tampil histogram masing-masing variabel input untuk mendapatkan ide tentang distribusi. Histogram adalah grafik dari suatu sebaran frekuensi yang dapat digunakan untuk melihat distribusi data beupa ukuran penyebaran dan pemusatan data, melihat adanya data outliner, dan mendeteksi adanya bimodus.
#
# # Kesimpulan:
# Berdasarkan hasil yang diberikan semua fitur memiliki bentuk persebaran unimodal yaitu histogram satu modus.Bentuk sebaran datauntuk sebagian besar fitur cenderung miring ke kiri, pada fitur eccentricity, extent, solidity, roundness, shapeFactor1, dan shapeFactor 4 bentuk sebaran data cenderung ke kanan, sedangkan pada fitur compactness dan shapeFitur3 bentuk sebaran data simetris.

# %% [markdown]
# ### f. visualisasi data menggunakan plot multivarian

# %%
# visualisasi data menggunakan plot multivarian (matriks scatter)
# import scatter_matrix
from pandas.plotting import scatter_matrix

# Membuat figur dengan ukuran lebih besar
fig = plt.figure(figsize=(16, 14))

# Membuat matriks scatter dengan subplot
# alpha: mengatur tingkat transparansi titik-titik pada scatter plot.
# figsize: mengatur ukuran gambar matriks scatter (baris, kolom)
# diagonal='hist': mengatur bahwa elemen diagonal dalam matriks akan berisi histogram untuk setiap fitur.
# color:mengatur warna plot scatter.
scatter_matrix(dataset, alpha=0.5, figsize=(16, 14), diagonal='hist', color='skyblue')

# Menampilkan matriks scatter
plt.show()

# %% [markdown]
# ### Penjelasan:
# kita bisa melihat interaksi antar variabel. Pertama, kita lihat scatterplots dari semua pasang atribut. Hal ini dapat membantu melihat hubungan terstruktur antara variabel input (pola hubungan), arah hubungan, dan keeratan hubungan.
#
# - Pola Hubungan: Scatterplot memungkinkan kita untuk mengidentifikasi pola hubungan antara dua variabel. Pola dapat berupa linear (garis lurus), eksponensial (meningkat secara eksponensial), logaritmik (menurun secara logaritmik), atau pola non-linear lainnya. Dengan memperhatikan pola ini, kita dapat mengidentifikasi bagaimana satu variabel berubah seiring dengan perubahan variabel lainnya.
#
# - Arah Hubungan: Scatterplot juga membantu kita menentukan arah hubungan antara dua variabel. Jika titik-titik cenderung bergerak dari kiri ke kanan saat salah satu variabel meningkat, ini menunjukkan hubungan positif, yang berarti bahwa kenaikan dalam satu variabel cenderung disertai dengan kenaikan dalam variabel lainnya. Sebaliknya, jika titik-titik cenderung bergerak dari kiri atas ke kanan bawah saat salah satu variabel meningkat, ini menunjukkan hubungan negatif, yang berarti bahwa kenaikan dalam satu variabel disertai dengan penurunan dalam variabel lainnya.
#
# - Keeratan Hubungan: Keeratan hubungan antara dua variabel dapat diamati dengan melihat seberapa erat titik-titik berdekatan satu sama lain dalam scatterplot. Semakin erat titik-titik berdekatan, semakin erat hubungan antara variabelnya. Jika titik-titik tersebar dengan lebar dan tidak mengikuti pola tertentu, ini menunjukkan hubungan yang lebih lemah.
#
# - Pencilan (Outliers): Scatterplot juga membantu mengidentifikasi pencilan (outliers) dalam data. Pencilan adalah titik-titik yang terletak jauh dari pola hubungan umum antara dua variabel. Identifikasi pencilan dapat memberikan wawasan tentang anomali dalam data.
#
# ### Kesimpulan:
# Hubungan antar 2 variabel fitur menghasilkan beragam variasi hubungan. Berdasarkan pola hubungan:
# linear seperti hubungan antar variabel area dan convexArea.
# eksponensial seperti hubungan antar variabel aspectRation dan eccentricity.
# logaritmik seperti hubungan antar variabel compactness dan eccentricity.
# Berdasarkan arah hubungan:
# positif seperti pada hubungan antar variabel aspectRation dan eccentricity.
# negatif seperti pada hubungan antar variabel compactness dan eccentricity.
# Berdasarkan kekuatan hubungan:
# menyebar ke segala arah tanpa pola khusus (sangat lemah) seperti pada hubungan antar variabel shapeFactor4 dan extent
# menyebar ke segala arah mulai terbentuk pola tertentu (sangat lemah) seperti pada hubungan antar variabel majorAxisLength dan minorAxisLength.
# mengerucut hampir membentuk pola yang jelas (kuat) seperti pada hubungan antar variabel perimeter dan majorAxisLength
# menyebar hampir menyerupai dua garis lurus (sangat kuat) seperti pada hubungan antar variabel compactness dan shapeFactor3.
